# %%
# %reload_ext lab_black

# %%
import pandas as pd
import numpy as np
from datetime import datetime
from pathlib import Path
import seaborn as sns
import datetime
from plotly.subplots import make_subplots

WORK_DIR = Path.cwd()
ANALYSIS_DIR = WORK_DIR / "analysis"

# %%
import plotly.graph_objs as go

# %%
print(WORK_DIR)
# Out:
# /home/sam/Documents/projects/datascience

# %%
import pygraphviz

# %%
import pybaobabdt
import pandas as pd
from scipy.io import arff
from sklearn.tree import DecisionTreeClassifier

# %%
data = arff.loadarff(WORK_DIR / "data" / "vehicle.arff")

# %%
df = pd.DataFrame(data[0])

y = list(df["class"])
features = list(df.columns)
features.remove("class")
X = df.loc[:, features]

clf = DecisionTreeClassifier().fit(X, y)

# %%
ax = pybaobabdt.drawTree(clf, size=10, dpi=72, features=features,)

# %%
ax.get_figure().savefig("tree.png", format="png", dpi=300, transparent=True)

# %%
df.T
# Out:
#                               0       1        2       3       4       5    \
# COMPACTNESS                  95.0    91.0    104.0    93.0    85.0   107.0
# CIRCULARITY                  48.0    41.0     50.0    41.0    44.0    57.0
# DISTANCE_CIRCULARITY         83.0    84.0    106.0    82.0    70.0   106.0
# RADIUS_RATIO                178.0   141.0    209.0   159.0   205.0   172.0
# PR.AXIS_ASPECT_RATIO         72.0    57.0     66.0    63.0   103.0    50.0
# MAX.LENGTH_ASPECT_RATIO      10.0     9.0     10.0     9.0    52.0     6.0
# SCATTER_RATIO               162.0   149.0    207.0   144.0   149.0   255.0
# ELONGATEDNESS                42.0    45.0     32.0    46.0    45.0    26.0
# PR.AXIS_RECTANGULARITY       20.0    19.0     23.0    19.0    19.0    28.0
# MAX.LENGTH_RECTANGULARITY   159.0   143.0    158.0   143.0   144.0   169.0
# SCALED_VARIANCE_MAJOR       176.0   170.0    223.0   160.0   241.0   280.0
# SCALED_VARIANCE_MINOR       379.0   330.0    635.0   309.0   325.0   957.0
# SCALED_RADIUS_OF_GYRATION   184.0   158.0    220.0   127.0   188.0   264.0
# SKEWNESS_ABOUT_MAJOR         70.0    72.0     73.0    63.0   127.0    85.0
# SKEWNESS_ABOUT_MINOR          6.0     9.0     14.0     6.0     9.0     5.0
# KURTOSIS_ABOUT_MAJOR         16.0    14.0      9.0    10.0    11.0     9.0
# KURTOSIS_ABOUT_MINOR        187.0   189.0    188.0   199.0   180.0   181.0
# HOLLOWS_RATIO               197.0   199.0    196.0   207.0   183.0   183.0
# class                      b'van'  b'van'  b'saab'  b'van'  b'bus'  b'bus'
#
#                               6       7       8        9    ...     836  \
# COMPACTNESS                  97.0    90.0    86.0     93.0  ...    87.0
# CIRCULARITY                  43.0    43.0    34.0     44.0  ...    45.0
# DISTANCE_CIRCULARITY         73.0    66.0    62.0     98.0  ...    66.0
# RADIUS_RATIO                173.0   157.0   140.0    197.0  ...   139.0
# PR.AXIS_ASPECT_RATIO         65.0    65.0    61.0     62.0  ...    58.0
# MAX.LENGTH_ASPECT_RATIO       6.0     9.0     7.0     11.0  ...     8.0
# SCATTER_RATIO               153.0   137.0   122.0    183.0  ...   140.0
# ELONGATEDNESS                42.0    48.0    54.0     36.0  ...    47.0
# PR.AXIS_RECTANGULARITY       19.0    18.0    17.0     22.0  ...    18.0
# MAX.LENGTH_RECTANGULARITY   143.0   146.0   127.0    146.0  ...   148.0
# SCALED_VARIANCE_MAJOR       176.0   162.0   141.0    202.0  ...   168.0
# SCALED_VARIANCE_MINOR       361.0   281.0   223.0    505.0  ...   294.0
# SCALED_RADIUS_OF_GYRATION   172.0   164.0   112.0    152.0  ...   175.0
# SKEWNESS_ABOUT_MAJOR         66.0    67.0    64.0     64.0  ...    73.0
# SKEWNESS_ABOUT_MINOR         13.0     3.0     2.0      4.0  ...     3.0
# KURTOSIS_ABOUT_MAJOR          1.0     3.0    14.0     14.0  ...    12.0
# KURTOSIS_ABOUT_MINOR        200.0   193.0   200.0    195.0  ...   188.0
# HOLLOWS_RATIO               204.0   202.0   208.0    204.0  ...   196.0
# class                      b'bus'  b'van'  b'van'  b'saab'  ...  b'van'
#
#                                837     838     839      840      841     842  \
# COMPACTNESS                   94.0    95.0    90.0     93.0     93.0    89.0
# CIRCULARITY                   46.0    43.0    44.0     34.0     39.0    46.0
# DISTANCE_CIRCULARITY          77.0    76.0    72.0     66.0     87.0    84.0
# RADIUS_RATIO                 169.0   142.0   157.0    140.0    183.0   163.0
# PR.AXIS_ASPECT_RATIO          60.0    57.0    64.0     56.0     64.0    66.0
# MAX.LENGTH_ASPECT_RATIO        8.0    10.0     8.0      7.0      8.0    11.0
# SCATTER_RATIO                158.0   151.0   137.0    130.0    169.0   159.0
# ELONGATEDNESS                 42.0    44.0    48.0     51.0     40.0    43.0
# PR.AXIS_RECTANGULARITY        20.0    19.0    18.0     18.0     20.0    20.0
# MAX.LENGTH_RECTANGULARITY    148.0   149.0   144.0    120.0    134.0   159.0
# SCALED_VARIANCE_MAJOR        181.0   173.0   159.0    151.0    200.0   173.0
# SCALED_VARIANCE_MINOR        373.0   339.0   283.0    251.0    422.0   368.0
# SCALED_RADIUS_OF_GYRATION    181.0   159.0   171.0    114.0    149.0   176.0
# SKEWNESS_ABOUT_MAJOR          67.0    71.0    65.0     62.0     72.0    72.0
# SKEWNESS_ABOUT_MINOR          12.0     2.0     9.0      5.0      7.0     1.0
# KURTOSIS_ABOUT_MAJOR           2.0    23.0     4.0     29.0     25.0    20.0
# KURTOSIS_ABOUT_MINOR         193.0   187.0   196.0    201.0    188.0   186.0
# HOLLOWS_RATIO                199.0   200.0   203.0    207.0    195.0   197.0
# class                      b'saab'  b'van'  b'van'  b'opel'  b'saab'  b'van'
#
#                                843      844     845
# COMPACTNESS                  106.0     86.0    85.0
# CIRCULARITY                   54.0     36.0    36.0
# DISTANCE_CIRCULARITY         101.0     78.0    66.0
# RADIUS_RATIO                 222.0    146.0   123.0
# PR.AXIS_ASPECT_RATIO          67.0     58.0    55.0
# MAX.LENGTH_ASPECT_RATIO       12.0      7.0     5.0
# SCATTER_RATIO                222.0    135.0   120.0
# ELONGATEDNESS                 30.0     50.0    56.0
# PR.AXIS_RECTANGULARITY        25.0     18.0    17.0
# MAX.LENGTH_RECTANGULARITY    173.0    124.0   128.0
# SCALED_VARIANCE_MAJOR        228.0    155.0   140.0
# SCALED_VARIANCE_MINOR        721.0    270.0   212.0
# SCALED_RADIUS_OF_GYRATION    200.0    148.0   131.0
# SKEWNESS_ABOUT_MAJOR          70.0     66.0    73.0
# SKEWNESS_ABOUT_MINOR           3.0      0.0     1.0
# KURTOSIS_ABOUT_MAJOR           4.0     25.0    18.0
# KURTOSIS_ABOUT_MINOR         187.0    190.0   186.0
# HOLLOWS_RATIO                201.0    195.0   190.0
# class                      b'saab'  b'saab'  b'van'
#
# [19 rows x 846 columns]

# %%
import easygui

# %%
easygui.ynbox('Shall I continue?', 'Title', ('Yes', 'No'))
# Out:
# True

# %%
password=easygui.passwordbox()

# %%
password
# Out:
# 'potato'

# %% [markdown]
# # dataframes to text

# %%
df = pd.DataFrame(
    {
        "string": list("abc"),
        "int64": list(range(1, 4)),
        "uint8": np.arange(3, 6).astype("u1"),
        "float64": np.arange(4.0, 7.0),
        "bool1": [True, False, True],
        "bool2": [False, True, False],
        "dates": pd.date_range("now", periods=3),
        "category": pd.Series(list("ABC")).astype("category"),
    }
)


df["tdeltas"] = df.dates.diff()

df["uint64"] = np.arange(3, 6).astype("u8")

df["other_dates"] = pd.date_range("20130101", periods=3)

df["tz_aware_dates"] = pd.date_range("20130101", periods=3, tz="US/Eastern")

df
# Out:
#   string  int64  uint8  float64  bool1  bool2                      dates  \
# 0      a      1      3      4.0   True  False 2022-10-27 21:54:58.043516
# 1      b      2      4      5.0  False   True 2022-10-28 21:54:58.043516
# 2      c      3      5      6.0   True  False 2022-10-29 21:54:58.043516
#
#   category tdeltas  uint64 other_dates            tz_aware_dates
# 0        A     NaT       3  2013-01-01 2013-01-01 00:00:00-05:00
# 1        B  1 days       4  2013-01-02 2013-01-02 00:00:00-05:00
# 2        C  1 days       5  2013-01-03 2013-01-03 00:00:00-05:00

# %%
def type_mapper(string: str) -> str:
    string = string.lower()

    if "int" in string or "bool" in string:
        result = "bigint"

    elif "date" in string:
        result = "date"

    elif "float" in string:
        result = "decimal(32,8)"

    else:
        result = "varchar(32)"

    return result.upper()

# %%
def generate_create_query(df: pd.DataFrame, schema: str, table_name: str) -> str:

    df_meta = pd.DataFrame(df.dtypes).reset_index().astype(str)
    df_meta.columns = ["columnname", "python_dtype"]

    df_meta.loc[:, "teradata_dtype"] = df_meta.python_dtype.str.lower().map(
        lambda x: type_mapper(x)
    )
    print(df_meta)

    primary_index = ", ".join(
        [x for x in (df_meta.columnname) if "id" in x or "class" in x]
    )
    print(f"\nPrimary Index: {primary_index}")

    query = (
        f"create set table {schema}.{table_name} , no fallback ("
        + ", ".join(list(df_meta.columnname + " as " + df_meta.teradata_dtype))
        + f") primary index({primary_index});"
    )
    return query

# %%
generate_create_query(df=df, schema="prd_fadm", table_name="test")
# Out:
#                    columnname python_dtype teradata_dtype
# 0                 COMPACTNESS      float64  DECIMAL(32,8)
# 1                 CIRCULARITY      float64  DECIMAL(32,8)
# 2        DISTANCE_CIRCULARITY      float64  DECIMAL(32,8)
# 3                RADIUS_RATIO      float64  DECIMAL(32,8)
# 4        PR.AXIS_ASPECT_RATIO      float64  DECIMAL(32,8)
# 5     MAX.LENGTH_ASPECT_RATIO      float64  DECIMAL(32,8)
# 6               SCATTER_RATIO      float64  DECIMAL(32,8)
# 7               ELONGATEDNESS      float64  DECIMAL(32,8)
# 8      PR.AXIS_RECTANGULARITY      float64  DECIMAL(32,8)
# 9   MAX.LENGTH_RECTANGULARITY      float64  DECIMAL(32,8)
# 10      SCALED_VARIANCE_MAJOR      float64  DECIMAL(32,8)
# 11      SCALED_VARIANCE_MINOR      float64  DECIMAL(32,8)
# 12  SCALED_RADIUS_OF_GYRATION      float64  DECIMAL(32,8)
# 13       SKEWNESS_ABOUT_MAJOR      float64  DECIMAL(32,8)
# 14       SKEWNESS_ABOUT_MINOR      float64  DECIMAL(32,8)
# 15       KURTOSIS_ABOUT_MAJOR      float64  DECIMAL(32,8)
# 16       KURTOSIS_ABOUT_MINOR      float64  DECIMAL(32,8)
# 17              HOLLOWS_RATIO      float64  DECIMAL(32,8)
# 18                      class       object    VARCHAR(32)
#
# Primary Index: class
# 'create set table prd_fadm.test , no fallback (COMPACTNESS as DECIMAL(32,8), CIRCULARITY as DECIMAL(32,8), DISTANCE_CIRCULARITY as DECIMAL(32,8), RADIUS_RATIO as DECIMAL(32,8), PR.AXIS_ASPECT_RATIO as DECIMAL(32,8), MAX.LENGTH_ASPECT_RATIO as DECIMAL(32,8), SCATTER_RATIO as DECIMAL(32,8), ELONGATEDNESS as DECIMAL(32,8), PR.AXIS_RECTANGULARITY as DECIMAL(32,8), MAX.LENGTH_RECTANGULARITY as DECIMAL(32,8), SCALED_VARIANCE_MAJOR as DECIMAL(32,8), SCALED_VARIANCE_MINOR as DECIMAL(32,8), SCALED_RADIUS_OF_GYRATION as DECIMAL(32,8), SKEWNESS_ABOUT_MAJOR as DECIMAL(32,8), SKEWNESS_ABOUT_MINOR as DECIMAL(32,8), KURTOSIS_ABOUT_MAJOR as DECIMAL(32,8), KURTOSIS_ABOUT_MINOR as DECIMAL(32,8), HOLLOWS_RATIO as DECIMAL(32,8), class as VARCHAR(32)) primary index(class);'

# %% [markdown]
# # other stuff

# %%
test1_df = pd.DataFrame({"value": np.random.logistic(size=5_000)})

test1_df["group"] = (
    pd.Series((["a", "b", "c", "d", "e"] * 1_000))
    .sample(frac=1)
    .reset_index()
    .loc[:, 0]
)

# %%
test2_df = pd.DataFrame({"value": np.random.logistic(size=5_000)})

test2_df["group"] = (
    pd.Series((["a", "b", "c", "d", "e"] * 1_000))
    .sample(frac=1)
    .reset_index()
    .loc[:, 0]
)

# %%
test2_df
# Out:
#          value group
# 0     1.327606     b
# 1     0.285827     b
# 2    -0.755987     b
# 3    -0.909903     d
# 4    -2.900991     b
# ...        ...   ...
# 4995 -0.284643     b
# 4996 -6.905207     e
# 4997 -0.629123     c
# 4998 -0.521771     e
# 4999  0.187269     d
#
# [5000 rows x 2 columns]

# %%
test1_df
# Out:
#          value group
# 0    -0.847822     b
# 1     0.471187     d
# 2     1.296684     a
# 3    -0.882376     c
# 4     0.326620     c
# ...        ...   ...
# 4995 -0.072087     e
# 4996 -1.215813     c
# 4997 -4.255233     a
# 4998  0.073360     b
# 4999 -0.150795     e
#
# [5000 rows x 2 columns]

# %%
_groupby_ = test1_df.groupby(["group"])
_temp1_df_ = pd.DataFrame(
    {
        "mean": _groupby_.value.mean(),
        "median": _groupby_.value.median(),
        "count": _groupby_.value.count(),
    }
).reset_index()

_groupby_ = test2_df.groupby(["group"])
_temp2_df_ = pd.DataFrame(
    {
        "mean": _groupby_.value.mean(),
        "median": _groupby_.value.median(),
        "count": _groupby_.value.count(),
    }
).reset_index()

# %%
_temp1_df_
# Out:
#   group      mean    median  count
# 0     a  0.038685  0.051340   1000
# 1     b -0.014863 -0.020549   1000
# 2     c  0.071575  0.026413   1000
# 3     d -0.065374 -0.042641   1000
# 4     e -0.045264 -0.036919   1000

# %%
from scipy.stats import wilcoxon, mannwhitneyu

# %%
pvalue_df = pd.DataFrame()

for x in _temp1_df_.group.drop_duplicates():
    _series_1_ = test1_df.loc[test1_df.group == x, "value"]
    _series_2_ = test2_df.loc[test2_df.group == x, "value"]

    res = wilcoxon(x=_series_1_, y=_series_2_)
    res_mann = mannwhitneyu(x=_series_1_, y=_series_2_)

    sub_df = pd.DataFrame(
        {
            "group": [x],
            "p_value_wilcoxon": [res.pvalue],
            "p_value_mann": [res_mann.pvalue],
        }
    )

    pvalue_df = pd.concat([pvalue_df, sub_df])

pvalue_df = pvalue_df.reset_index().drop(columns=["index"])

# %%
result_df = _temp1_df_
for _df_ in [_temp2_df_, pvalue_df]:
    result_df = pd.merge(
        left=result_df, right=_df_, left_on="group", right_on="group", how="outer"
    )

result_df.sort_values("p_value_mann", ascending=True)
# Out:
#   group    mean_x  median_x  count_x    mean_y  median_y  count_y  \
# 2     c  0.014643  0.062352     1000 -0.147971 -0.113617     1000
# 1     b  0.029830  0.044050     1000 -0.086299 -0.113369     1000
# 0     a -0.075065 -0.068085     1000 -0.015852 -0.005437     1000
# 3     d -0.071810  0.035770     1000  0.008237 -0.004506     1000
# 4     e -0.035258 -0.038787     1000  0.035833 -0.021271     1000
#
#    p_value_wilcoxon  p_value_mann
# 2          0.041084      0.029047
# 1          0.105340      0.057816
# 0          0.492851      0.416747
# 3          0.463716      0.754476
# 4          0.709520      0.815958
